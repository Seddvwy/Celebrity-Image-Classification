# %%
import numpy as np 
import cv2
import matplotlib 
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./test_images/1624894993966.jpg')
img.shape
# Out:
# (200, 300, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (200, 300)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3,5)
faces
# Out:
# array([[128,  46,  56,  56]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (128, 46, 56, 56)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
def get_cropped_image_if_2_eyes(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for(x,y,w,h) in faces :
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >=2:
            return roi_color

# %%
plt.imshow(get_cropped_image_if_2_eyes('./dataset/drake/0x0.jpg'))

# %%
path_to_data = "./dataset"
path_to_cr_data = "./dataset/cropped/"

# %%
import os 
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset\\cristiano_ronaldo',
#  './dataset\\drake',
#  './dataset\\kanye_west',
#  './dataset\\leonardo_dicaprio',
#  './dataset\\lionel_messi',
#  './dataset\\travis_scott']

# %%
import shutil 
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs :
    count = 1
    celebrity_name = img_dir.split('\\')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None :
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.mkdir(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print('Generation cropped images in folder: ', cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count+=1
# Out:
# cristiano_ronaldo
# Generation cropped images in folder:  ./dataset/cropped/cristiano_ronaldo
# drake
# Generation cropped images in folder:  ./dataset/cropped/drake
# kanye_west
# Generation cropped images in folder:  ./dataset/cropped/kanye_west
# leonardo_dicaprio
# Generation cropped images in folder:  ./dataset/cropped/leonardo_dicaprio
# lionel_messi
# Generation cropped images in folder:  ./dataset/cropped/lionel_messi
# travis_scott
# Generation cropped images in folder:  ./dataset/cropped/travis_scott

# %%
import numpy as np 
import pywt 
import cv2

# def w2d(img, mode='haar', level=1):
#     imArray = img
#     #CONNVERT TO GRAYSCALE
#     imArray = cv2.cvtColor(imArray, cv2.COLOR_RGB2GRAY)
#     #CONVERT TO FLOAT
#     imArray = np.float32(imArray)
#     imArray/=255
    
#     coeffs = pywt.wavedec2(imArray,mode, level=level)
    
#     coeffs_H = list(coeffs)
#     coeffs_H[0] *= 0;
    
#     imArray_H = pywt.wavedec2(coeffs_H,mode);
#     imArray_H *= 255;
#     imArray_H = np.uint8(imArray_H)
    
#     return imArray_H
    
    
def w2d(img, mode='haar', level=1):
    imArray = img
    # CONVERT TO GRAYSCALE
    imArray = cv2.cvtColor(imArray, cv2.COLOR_RGB2GRAY)
    # CONVERT TO FLOAT
    imArray = np.float32(imArray)
    imArray /= 255
    
    coeffs = pywt.wavedec2(imArray, mode, level=level)
    
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0
    
    imArray_H = pywt.waverec2(coeffs_H, mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
celebrity_file_names_dict
# Out:
# {'cristiano_ronaldo': ['./dataset/cropped/cristiano_ronaldo/cristiano_ronaldo1.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo2.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo3.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo4.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo5.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo6.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo7.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo8.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo9.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo10.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo11.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo12.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo13.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo14.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo15.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo16.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo17.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo18.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo19.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo20.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo21.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo22.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo23.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo24.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo25.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo26.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo27.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo28.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo29.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo30.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo31.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo32.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo33.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo34.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo35.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo36.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo37.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo38.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo39.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo40.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo41.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo42.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo43.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo44.png',
#   './dataset/cropped/cristiano_ronaldo/cristiano_ronaldo45.png'],
#  'drake': ['./dataset/cropped/drake/drake1.png',
#   './dataset/cropped/drake/drake2.png',
#   './dataset/cropped/drake/drake3.png',
#   './dataset/cropped/drake/drake4.png',
#   './dataset/cropped/drake/drake5.png',
#   './dataset/cropped/drake/drake6.png',
#   './dataset/cropped/drake/drake7.png',
#   './dataset/cropped/drake/drake8.png',
#   './dataset/cropped/drake/drake9.png',
#   './dataset/cropped/drake/drake10.png',
#   './dataset/cropped/drake/drake11.png',
#   './dataset/cropped/drake/drake12.png',
#   './dataset/cropped/drake/drake13.png',
#   './dataset/cropped/drake/drake14.png',
#   './dataset/cropped/drake/drake15.png',
#   './dataset/cropped/drake/drake16.png',
#   './dataset/cropped/drake/drake17.png',
#   './dataset/cropped/drake/drake18.png',
#   './dataset/cropped/drake/drake19.png',
#   './dataset/cropped/drake/drake20.png',
#   './dataset/cropped/drake/drake21.png',
#   './dataset/cropped/drake/drake22.png',
#   './dataset/cropped/drake/drake23.png',
#   './dataset/cropped/drake/drake24.png',
#   './dataset/cropped/drake/drake25.png',
#   './dataset/cropped/drake/drake26.png',
#   './dataset/cropped/drake/drake27.png',
#   './dataset/cropped/drake/drake28.png',
#   './dataset/cropped/drake/drake29.png',
#   './dataset/cropped/drake/drake30.png',
#   './dataset/cropped/drake/drake31.png',
#   './dataset/cropped/drake/drake32.png',
#   './dataset/cropped/drake/drake33.png',
#   './dataset/cropped/drake/drake34.png',
#   './dataset/cropped/drake/drake35.png',
#   './dataset/cropped/drake/drake36.png',
#   './dataset/cropped/drake/drake37.png',
#   './dataset/cropped/drake/drake38.png',
#   './dataset/cropped/drake/drake39.png',
#   './dataset/cropped/drake/drake40.png',
#   './dataset/cropped/drake/drake41.png',
#   './dataset/cropped/drake/drake42.png',
#   './dataset/cropped/drake/drake43.png',
#   './dataset/cropped/drake/drake44.png',
#   './dataset/cropped/drake/drake45.png',
#   './dataset/cropped/drake/drake46.png',
#   './dataset/cropped/drake/drake47.png',
#   './dataset/cropped/drake/drake48.png',
#   './dataset/cropped/drake/drake49.png',
#   './dataset/cropped/drake/drake50.png',
#   './dataset/cropped/drake/drake51.png'],
#  'kanye_west': ['./dataset/cropped/kanye_west/kanye_west1.png',
#   './dataset/cropped/kanye_west/kanye_west2.png',
#   './dataset/cropped/kanye_west/kanye_west3.png',
#   './dataset/cropped/kanye_west/kanye_west4.png',
#   './dataset/cropped/kanye_west/kanye_west5.png',
#   './dataset/cropped/kanye_west/kanye_west6.png',
#   './dataset/cropped/kanye_west/kanye_west7.png',
#   './dataset/cropped/kanye_west/kanye_west8.png',
#   './dataset/cropped/kanye_west/kanye_west9.png',
#   './dataset/cropped/kanye_west/kanye_west10.png',
#   './dataset/cropped/kanye_west/kanye_west11.png',
#   './dataset/cropped/kanye_west/kanye_west12.png',
#   './dataset/cropped/kanye_west/kanye_west13.png',
#   './dataset/cropped/kanye_west/kanye_west14.png',
#   './dataset/cropped/kanye_west/kanye_west15.png',
#   './dataset/cropped/kanye_west/kanye_west16.png',
#   './dataset/cropped/kanye_west/kanye_west17.png',
#   './dataset/cropped/kanye_west/kanye_west18.png',
#   './dataset/cropped/kanye_west/kanye_west19.png',
#   './dataset/cropped/kanye_west/kanye_west20.png',
#   './dataset/cropped/lionel_messi/lionel_messi7.png',
#   './dataset/cropped/lionel_messi/lionel_messi8.png',
#   './dataset/cropped/lionel_messi/lionel_messi9.png',
#   './dataset/cropped/lionel_messi/lionel_messi10.png',
#   './dataset/cropped/lionel_messi/lionel_messi11.png',
#   './dataset/cropped/lionel_messi/lionel_messi12.png',
#   './dataset/cropped/lionel_messi/lionel_messi13.png',
#   './dataset/cropped/lionel_messi/lionel_messi14.png',
#   './dataset/cropped/lionel_messi/lionel_messi15.png',
#   './dataset/cropped/lionel_messi/lionel_messi16.png',
#   './dataset/cropped/lionel_messi/lionel_messi17.png',
#   './dataset/cropped/lionel_messi/lionel_messi18.png',
#   './dataset/cropped/lionel_messi/lionel_messi19.png',
#   './dataset/cropped/lionel_messi/lionel_messi20.png',
#   './dataset/cropped/lionel_messi/lionel_messi21.png',
#   './dataset/cropped/lionel_messi/lionel_messi22.png',
#   './dataset/cropped/lionel_messi/lionel_messi23.png',
#   './dataset/cropped/lionel_messi/lionel_messi24.png',
#   './dataset/cropped/lionel_messi/lionel_messi25.png',
#   './dataset/cropped/lionel_messi/lionel_messi26.png',
#   './dataset/cropped/lionel_messi/lionel_messi27.png',
#   './dataset/cropped/lionel_messi/lionel_messi28.png',
#   './dataset/cropped/lionel_messi/lionel_messi29.png',
#   './dataset/cropped/lionel_messi/lionel_messi30.png',
#   './dataset/cropped/lionel_messi/lionel_messi31.png',
#   './dataset/cropped/lionel_messi/lionel_messi32.png',
#   './dataset/cropped/lionel_messi/lionel_messi33.png',
#   './dataset/cropped/lionel_messi/lionel_messi34.png',
#   './dataset/cropped/lionel_messi/lionel_messi35.png',
#   './dataset/cropped/lionel_messi/lionel_messi36.png',
#   './dataset/cropped/lionel_messi/lionel_messi37.png',
#   './dataset/cropped/lionel_messi/lionel_messi38.png',
#   './dataset/cropped/lionel_messi/lionel_messi39.png',
#   './dataset/cropped/lionel_messi/lionel_messi40.png',
#   './dataset/cropped/lionel_messi/lionel_messi41.png',
#   './dataset/cropped/lionel_messi/lionel_messi42.png',
#   './dataset/cropped/lionel_messi/lionel_messi43.png',
#   './dataset/cropped/lionel_messi/lionel_messi44.png'],
#  'travis_scott': ['./dataset/cropped/travis_scott/travis_scott1.png',
#   './dataset/cropped/travis_scott/travis_scott2.png',
#   './dataset/cropped/travis_scott/travis_scott3.png',
#   './dataset/cropped/travis_scott/travis_scott4.png',
#   './dataset/cropped/travis_scott/travis_scott5.png',
#   './dataset/cropped/travis_scott/travis_scott6.png',
#   './dataset/cropped/travis_scott/travis_scott7.png',
#   './dataset/cropped/travis_scott/travis_scott8.png',
#   './dataset/cropped/travis_scott/travis_scott9.png',
#   './dataset/cropped/travis_scott/travis_scott10.png',
#   './dataset/cropped/travis_scott/travis_scott11.png',
#   './dataset/cropped/travis_scott/travis_scott12.png',
#   './dataset/cropped/travis_scott/travis_scott13.png',
#   './dataset/cropped/travis_scott/travis_scott14.png',
#   './dataset/cropped/travis_scott/travis_scott15.png',
#   './dataset/cropped/travis_scott/travis_scott16.png',
#   './dataset/cropped/travis_scott/travis_scott17.png',
#   './dataset/cropped/travis_scott/travis_scott18.png',
#   './dataset/cropped/travis_scott/travis_scott19.png',
#   './dataset/cropped/travis_scott/travis_scott20.png',
#   './dataset/cropped/travis_scott/travis_scott21.png',
#   './dataset/cropped/travis_scott/travis_scott22.png',
#   './dataset/cropped/travis_scott/travis_scott23.png',
#   './dataset/cropped/travis_scott/travis_scott24.png',
#   './dataset/cropped/travis_scott/travis_scott25.png',
#   './dataset/cropped/travis_scott/travis_scott26.png']}

# %%
cropped_image=get_cropped_image_if_2_eyes('./dataset/drake/0x0.jpg')
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
class_dict = {}
count=0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count+=1
class_dict
# Out:
# {'cristiano_ronaldo': 0,
#  'drake': 1,
#  'kanye_west': 2,
#  'leonardo_dicaprio': 3,
#  'lionel_messi': 4,
#  'travis_scott': 5}

# %%
X = []
y = []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scaled_raw_img = cv2.resize(img, (32,32))
        img_har = w2d(img,'db1',5)
        scaled_image_har = cv2.resize(img_har,(32,32))
        combined_image = np.vstack((scaled_raw_img.reshape(32*32*3,1),scaled_image_har.reshape(32*32,1)))
        X.append(combined_image)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 303

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (303, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,random_state=0)

pipe = Pipeline([('scaler', StandardScaler()),('svc',SVC(kernel='rbf',C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.75

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.50      0.62        10
#            1       0.93      0.93      0.93        14
#            2       0.62      0.71      0.67        14
#            3       0.69      0.83      0.75        24
#            4       1.00      0.60      0.75        10
#            5       0.60      0.75      0.67         4
#
#     accuracy                           0.75        76
#    macro avg       0.78      0.72      0.73        76
# weighted avg       0.78      0.75      0.75        76

# %% [markdown]
# # GridSearch

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm':{
        'model':svm.SVC(gamma='auto',probability=True),
        'params':{
            'svc__C':[1,10,100,1000],
            'svc__kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'randomforestclassifier__n_estimators':[1,5,10]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'logisticregression__C':[1,5,100]
        }
    }
}

# %%
scores=[]
best_estimators={}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(),mp['model'])
    clf = GridSearchCV(pipe, mp['params'],cv=5,return_train_score=False)
    clf.fit(X_train,y_train)
    scores.append({
        'model':algo,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score                                   best_params
# 0                  svm    0.700966        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1        random_forest    0.595266  {'randomforestclassifier__n_estimators': 10}
# 2  logistic_regression    0.771304                  {'logisticregression__C': 1}

# %%
# lrc = Pipeline([('scaler', StandardScaler()),('logisticregression',LogisticRegression(solver='liblinear',C=1,multi_class='auto'))])
# lrc.fit(X_train,y_train)
# lrc.score(X_test,y_test)
# Out:
# 0.75

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7631578947368421

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.75

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.618421052631579

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  0,  0,  2,  0,  0],
#        [ 0, 12,  1,  0,  0,  1],
#        [ 1,  1,  9,  1,  0,  2],
#        [ 2,  0,  2, 20,  0,  0],
#        [ 0,  0,  0,  3,  6,  1],
#        [ 0,  0,  1,  0,  0,  3]], dtype=int64)

# %%
import seaborn as sn 
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# ## save trained model

# %%
# !pip install joblib
import joblib

joblib.dump(best_clf,'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %% [markdown]
# ## save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
